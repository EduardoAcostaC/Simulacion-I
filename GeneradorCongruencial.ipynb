# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoAcostaC/Simulacion-I/blob/main/GeneradorCongruencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Generador Congruencial Lineal
#
# El generador congruencial lineal es un algoritmo que produce una secuencia de números pseudoaleatorios.
# Se define por la siguiente fórmula recursiva:
#
#  $ X_{n+1} = (a * X_n + c) mod m $
#
# Donde:
#
# * **X_n** es el número actual de la secuencia.
# * **X_(n+1)** es el siguiente número de la secuencia.
# * **a** es el multiplicador.
# * **c** es el incremento.
# * **m** es el módulo.
# * **X_0** es la semilla o valor inicial.
#
# La calidad del generador depende de la elección de los parámetros a, c, m y X_0.
# Un buen generador producirá una secuencia de números que parezca aleatoria y que tenga un ciclo de vida largo.

# %%
import pandas as pd
from IPython.display import display

# Parámetros del generador congruencial
a = 23   # Multiplicador
c = 67  # Incremento
m = 1000  # Módulo
x_0 = 15  # Semilla

# Funcion Generadora
def generador(a, c, m, x_0):
    """
    Genera un número pseudoaleatorio utilizando el método congruencial lineal.

    Args:
        a (int): Multiplicador.
        c (int): Incremento.
        m (int): Módulo.
        x_0 (int): Semilla.

    Returns:
        int: Número pseudoaleatorio generado.
    """
    x = (a * x_0 + c) % m
    return x

muestra = []
ciclo_vida = []  # Almacena la secuencia de números generados
se_repite = False  # Bandera para verificar si el generador se repite

# Bucle principal (iterar m veces o hasta que se repita)
for i in range(m):
    nuevo = generador(a, c, m, x_0)
    muestra.append([i, x_0, nuevo, nuevo / m])
    x_0 = nuevo
    ciclo_vida.append(x_0)

    # Verifica si el número ya se generó
    if x_0 in ciclo_vida[:-1]:
        se_repite = True
        print("Ciclo de vida del generador:", ciclo_vida[:i+1])
        print("El generador se repite en la iteración:", i + 1)
        break  # Detiene la generación si se repite

if not se_repite:
    print("El generador no se repite en el ciclo de vida.")

df = pd.DataFrame(muestra, columns=["Iteracion", "Xn", "X_n+1", "Xn/m"])
df_styled = df.style.set_properties(**{
    'background-color': 'lightblue',
    'color': 'black',
    'border-color': 'black',
    'border-width': '1px',
    'border-style': 'solid',
    'text-align': 'center'
})

display(df_styled)
print("Ciclo de vida del generador:", ciclo_vida)
# Out:
# Ciclo de vida del generador: [412, 543, 556, 855, 732, 903, 836, 295, 852, 663, 316, 335, 772, 823, 996, 975, 492, 383, 876, 215, 12, 343, 956, 55, 332, 703, 236, 495, 452, 463, 716, 535, 372, 623, 396, 175, 92, 183, 276, 415, 612, 143, 356, 255, 932, 503, 636, 695, 52, 263, 116, 735, 972, 423, 796, 375, 692, 983, 676, 615, 212, 943, 756, 455, 532, 303, 36, 895, 652, 63, 516, 935, 572, 223, 196, 575, 292, 783, 76, 815, 812, 743, 156, 655, 132, 103, 436, 95, 252, 863, 916, 135, 172, 23, 596, 775, 892, 583, 476, 15, 412]
# El generador se repite en la iteración: 101
# <style type="text/css">
# #T_fd375_row0_col0, #T_fd375_row0_col1, #T_fd375_row0_col2, #T_fd375_row0_col3, #T_fd375_row1_col0, #T_fd375_row1_col1, #T_fd375_row1_col2, #T_fd375_row1_col3, #T_fd375_row2_col0, #T_fd375_row2_col1, #T_fd375_row2_col2, #T_fd375_row2_col3, #T_fd375_row3_col0, #T_fd375_row3_col1, #T_fd375_row3_col2, #T_fd375_row3_col3, #T_fd375_row4_col0, #T_fd375_row4_col1, #T_fd375_row4_col2, #T_fd375_row4_col3, #T_fd375_row5_col0, #T_fd375_row5_col1, #T_fd375_row5_col2, #T_fd375_row5_col3, #T_fd375_row6_col0, #T_fd375_row6_col1, #T_fd375_row6_col2, #T_fd375_row6_col3, #T_fd375_row7_col0, #T_fd375_row7_col1, #T_fd375_row7_col2, #T_fd375_row7_col3, #T_fd375_row8_col0, #T_fd375_row8_col1, #T_fd375_row8_col2, #T_fd375_row8_col3, #T_fd375_row9_col0, #T_fd375_row9_col1, #T_fd375_row9_col2, #T_fd375_row9_col3, #T_fd375_row10_col0, #T_fd375_row10_col1, #T_fd375_row10_col2, #T_fd375_row10_col3, #T_fd375_row11_col0, #T_fd375_row11_col1, #T_fd375_row11_col2, #T_fd375_row11_col3, #T_fd375_row12_col0, #T_fd375_row12_col1, #T_fd375_row12_col2, #T_fd375_row12_col3, #T_fd375_row13_col0, #T_fd375_row13_col1, #T_fd375_row13_col2, #T_fd375_row13_col3, #T_fd375_row14_col0, #T_fd375_row14_col1, #T_fd375_row14_col2, #T_fd375_row14_col3, #T_fd375_row15_col0, #T_fd375_row15_col1, #T_fd375_row15_col2, #T_fd375_row15_col3, #T_fd375_row16_col0, #T_fd375_row16_col1, #T_fd375_row16_col2, #T_fd375_row16_col3, #T_fd375_row17_col0, #T_fd375_row17_col1, #T_fd375_row17_col2, #T_fd375_row17_col3, #T_fd375_row18_col0, #T_fd375_row18_col1, #T_fd375_row18_col2, #T_fd375_row18_col3, #T_fd375_row19_col0, #T_fd375_row19_col1, #T_fd375_row19_col2, #T_fd375_row19_col3, #T_fd375_row20_col0, #T_fd375_row20_col1, #T_fd375_row20_col2, #T_fd375_row20_col3, #T_fd375_row21_col0, #T_fd375_row21_col1, #T_fd375_row21_col2, #T_fd375_row21_col3, #T_fd375_row22_col0, #T_fd375_row22_col1, #T_fd375_row22_col2, #T_fd375_row22_col3, #T_fd375_row23_col0, #T_fd375_row23_col1, #T_fd375_row23_col2, #T_fd375_row23_col3, #T_fd375_row24_col0, #T_fd375_row24_col1, #T_fd375_row24_col2, #T_fd375_row24_col3, #T_fd375_row25_col0, #T_fd375_row25_col1, #T_fd375_row25_col2, #T_fd375_row25_col3, #T_fd375_row26_col0, #T_fd375_row26_col1, #T_fd375_row26_col2, #T_fd375_row26_col3, #T_fd375_row27_col0, #T_fd375_row27_col1, #T_fd375_row27_col2, #T_fd375_row27_col3, #T_fd375_row28_col0, #T_fd375_row28_col1, #T_fd375_row28_col2, #T_fd375_row28_col3, #T_fd375_row29_col0, #T_fd375_row29_col1, #T_fd375_row29_col2, #T_fd375_row29_col3, #T_fd375_row30_col0, #T_fd375_row30_col1, #T_fd375_row30_col2, #T_fd375_row30_col3, #T_fd375_row31_col0, #T_fd375_row31_col1, #T_fd375_row31_col2, #T_fd375_row31_col3, #T_fd375_row32_col0, #T_fd375_row32_col1, #T_fd375_row32_col2, #T_fd375_row32_col3, #T_fd375_row33_col0, #T_fd375_row33_col1, #T_fd375_row33_col2, #T_fd375_row33_col3, #T_fd375_row34_col0, #T_fd375_row34_col1, #T_fd375_row34_col2, #T_fd375_row34_col3, #T_fd375_row35_col0, #T_fd375_row35_col1, #T_fd375_row35_col2, #T_fd375_row35_col3, #T_fd375_row36_col0, #T_fd375_row36_col1, #T_fd375_row36_col2, #T_fd375_row36_col3, #T_fd375_row37_col0, #T_fd375_row37_col1, #T_fd375_row37_col2, #T_fd375_row37_col3, #T_fd375_row38_col0, #T_fd375_row38_col1, #T_fd375_row38_col2, #T_fd375_row38_col3, #T_fd375_row39_col0, #T_fd375_row39_col1, #T_fd375_row39_col2, #T_fd375_row39_col3, #T_fd375_row40_col0, #T_fd375_row40_col1, #T_fd375_row40_col2, #T_fd375_row40_col3, #T_fd375_row41_col0, #T_fd375_row41_col1, #T_fd375_row41_col2, #T_fd375_row41_col3, #T_fd375_row42_col0, #T_fd375_row42_col1, #T_fd375_row42_col2, #T_fd375_row42_col3, #T_fd375_row43_col0, #T_fd375_row43_col1, #T_fd375_row43_col2, #T_fd375_row43_col3, #T_fd375_row44_col0, #T_fd375_row44_col1, #T_fd375_row44_col2, #T_fd375_row44_col3, #T_fd375_row45_col0, #T_fd375_row45_col1, #T_fd375_row45_col2, #T_fd375_row45_col3, #T_fd375_row46_col0, #T_fd375_row46_col1, #T_fd375_row46_col2, #T_fd375_row46_col3, #T_fd375_row47_col0, #T_fd375_row47_col1, #T_fd375_row47_col2, #T_fd375_row47_col3, #T_fd375 ...
# Ciclo de vida del generador: [412, 543, 556, 855, 732, 903, 836, 295, 852, 663, 316, 335, 772, 823, 996, 975, 492, 383, 876, 215, 12, 343, 956, 55, 332, 703, 236, 495, 452, 463, 716, 535, 372, 623, 396, 175, 92, 183, 276, 415, 612, 143, 356, 255, 932, 503, 636, 695, 52, 263, 116, 735, 972, 423, 796, 375, 692, 983, 676, 615, 212, 943, 756, 455, 532, 303, 36, 895, 652, 63, 516, 935, 572, 223, 196, 575, 292, 783, 76, 815, 812, 743, 156, 655, 132, 103, 436, 95, 252, 863, 916, 135, 172, 23, 596, 775, 892, 583, 476, 15, 412]
